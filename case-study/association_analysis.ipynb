# %% [markdown]
# # Association Analysis

# %% [markdown]
# ## Import all necessary libraries

# %%
#!fc-list :lang=zh family

# %%
import os
import glob
from functools import reduce
#import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#from scipy import stats
from sklearn.cluster import KMeans
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

#pd.set_option('display.max_rows', 10)
plt.rcParams['font.sans-serif'] = ['Noto Sans Mono CJK TC', 'sans-serif'] 
plt.rcParams['axes.unicode_minus'] = False

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
try:
    from google.colab import drive

    # Mount the folder "drive" on google drive to Colab Notebook
    drive.mount('/content/drive')
    path = '/content/drive/My Drive/wids-taipei/2020-WiDS-Taipei-MLCC-Workshop/dataset/*.csv'
except ModuleNotFoundError:
    path = '../data/*.csv'

# %% [markdown]
# ### Read data

# %%
# Read data
filenames = glob.glob(path)
pd_dict = {}

for filename in filenames:
    name = filename.split("/")[-1].split(".")[0]
    pd_dict[name] = pd.read_csv(os.path.join(filename))

purchase_data = pd_dict['customer_purchase_dataset']    
payments_data = pd_dict['order_payments_dataset']
reviews_data = pd_dict['order_reviews_dataset']
orders_data = pd_dict['orders_dataset']
customers_data = pd_dict['customers_dataset']

# %% [markdown]
# ## Association Analysis

# %%
def encode_units(x):
    if x <=0 :
        return 0
    else:
        return 1

# crosstab: compute a simple cross tabulation of two (or more) factors.
#           Default -> frequence
basket = pd.crosstab(purchase_data['customer_unique_id'], purchase_data['product_main_category'])
basket_sets = basket.applymap(encode_units)
basket_sets
# Out:
# product_main_category             3C  休閒生活  保健  其他  商業用途  嬰兒用品  安全配件  家居生活  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2   0     0   0   0     0     0     0     1
# 0000b849f77a49e4a4ce2b2a4ca5be3f   0     0   1   0     0     0     0     0
# 0000f46a3911fa3c0805444483337064   0     0   1   0     0     0     0     0
# 0000f6ccb0745a6a4b88665a16c9f078   0     0   0   0     0     0     0     1
# 0004aac84e0df4da2b147fca70cf8255   0     0   0   0     1     0     1     0
# ...                               ..   ...  ..  ..   ...   ...   ...   ...
# fffcf5a5ff07b0908bd4e2dbc735a684   0     0   1   0     0     0     0     0
# fffea47cd6d3cc0a88bd621562a9d061   0     0   0   0     0     1     0     0
# ffff371b4d645b6ecea244b27531430a   1     0   1   0     0     0     0     0
# ffff5962728ec6157033ef9805bacc48   0     1   0   0     0     0     0     0
# ffffd2657e2aad2907e67c3e9daecbeb   1     1   0   0     0     0     0     0
#
# product_main_category             家電  文具  書籍  服飾/配件  美食  藝術
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2   0   0   0      0   0   0
# 0000b849f77a49e4a4ce2b2a4ca5be3f   0   0   1      0   0   0
# 0000f46a3911fa3c0805444483337064   0   1   1      0   0   0
# 0000f6ccb0745a6a4b88665a16c9f078   1   0   0      0   0   0
# 0004aac84e0df4da2b147fca70cf8255   1   0   0      0   0   0
# ...                               ..  ..  ..    ...  ..  ..
# fffcf5a5ff07b0908bd4e2dbc735a684   0   0   1      0   1   0
# fffea47cd6d3cc0a88bd621562a9d061   0   0   0      0   0   0
# ffff371b4d645b6ecea244b27531430a   0   0   1      0   1   0
# ffff5962728ec6157033ef9805bacc48   0   0   0      0   0   0
# ffffd2657e2aad2907e67c3e9daecbeb   0   0   0      1   0   0
#
# [93350 rows x 14 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.05, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift")
rules = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]

# support(x, y) = number(x, y) / number(all samples)
rules['frequency'] = rules['support'] * len(basket_sets)
rules['length_1'] = rules['antecedents'].apply(lambda x: len(x))
rules['length_2'] = rules['consequents'].apply(lambda x: len(x))

rules_new = rules.loc[(rules['length_1'] == 1) & (rules['length_2'] == 1)]
rules_new["antecedents"] = rules_new["antecedents"].apply(lambda x: list(x)[0]).astype("unicode")
rules_new["consequents"] = rules_new["consequents"].apply(lambda x: list(x)[0]).astype("unicode")
rules_new
# Out:
# /home/kaka/opt/miniconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/kaka/opt/miniconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#    antecedents consequents   support  confidence       lift  frequency  \
# 0         休閒生活          3C  0.219646    0.631320   1.758847    20504.0
# 1           3C        休閒生活  0.219646    0.611932   1.758847    20504.0
# 2           書籍          3C  0.073583    0.327501   0.912412     6869.0
# 3           3C          書籍  0.073583    0.205002   0.912412     6869.0
# 4        服飾/配件          3C  0.104799    0.518992   1.445904     9783.0
# 5           3C       服飾/配件  0.104799    0.291969   1.445904     9783.0
# 6           美食          3C  0.055972    0.306956   0.855174     5225.0
# 7           3C          美食  0.055972    0.155938   0.855174     5225.0
# 8           書籍        休閒生活  0.071644    0.318871   0.916516     6688.0
# 9         休閒生活          書籍  0.071644    0.205924   0.916516     6688.0
# 10       服飾/配件        休閒生活  0.168838    0.836127   2.403242    15761.0
# 11        休閒生活       服飾/配件  0.168838    0.485282   2.403242    15761.0
# 12          美食        休閒生活  0.053476    0.293268   0.842925     4992.0
# 13        休閒生活          美食  0.053476    0.153704   0.842925     4992.0
# 14          書籍          保健  0.112608    0.501192   3.378070    10512.0
# 15          保健          書籍  0.112608    0.758989   3.378070    10512.0
# 16          美食          保健  0.061350    0.336447   2.267677     5727.0
# 17          保健          美食  0.061350    0.413502   2.267677     5727.0
# 18        安全配件        商業用途  0.055233    0.973565  15.639699     5156.0
# 19        商業用途        安全配件  0.055233    0.887283  15.639699     5156.0
# 20        家居生活          家電  0.235533    0.677002   2.611710    21987.0
# 21          家電        家居生活  0.235533    0.908629   2.611710    21987.0
# 22          書籍        家居生活  0.077461    0.344760   0.990959     7231.0
# 23        家居生活          書籍  0.077461    0.222650   0.990959     7231.0
# 24          美食        家居生活  0.061896    0.339443   0.975675     5778.0
# 25        家居生活          美食  0.061896    0.177911   0.975675     5778.0
# 26          書籍          家電  0.063964    0.284686   1.098249     5971.0
# 27          家電          書籍  0.063964    0.246756   1.098249     5971.0
# 28          美食          家電  0.050616    0.277582   1.070844     4725.0
# 29          家電          美食  0.050616    0.195264   1.070844     4725.0
# 30          書籍          美食  0.156058    0.694574   3.809100    14568.0
# 31          美食          書籍  0.156058    0.855834   3.809100    14568.0
#
#     length_1  length_2
# 0          1         1
# 1          1         1
# 2          1         1
# 3          1         1
# 4          1         1
# 5          1         1
# 6          1         1
# 7          1         1
# 8          1         1
# 9          1         1
# 10         1         1
# 11         1         1
# 12         1         1
# 13         1         1
# 14         1         1
# 15         1         1
# 16         1         1
# 17         1         1
# 18         1         1
# 19         1         1
# 20         1         1
# 21         1         1
# 22         1         1
# 23         1         1
# 24         1         1
# 25         1         1
# 26         1         1
# 27         1         1
# 28         1         1
# 29         1         1
# 30         1         1
# 31         1         1

# %%
cm = sns.light_palette((260, 75, 60), input="husl", as_cmap=True)

support_data = rules_new.groupby(['antecedents', 'consequents']).apply(lambda x: x.sort_values('support', ascending=False))
support_data = support_data[['support']].droplevel(2)
s = support_data.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_2f324600_1705_11ea_b211_887873aedd0frow0_col0 {
#             background-color:  #8094e6;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow1_col0 {
#             background-color:  #dce1f8;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow2_col0 {
#             background-color:  #c8d0f4;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow3_col0 {
#             background-color:  #e7eafa;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow4_col0 {
#             background-color:  #8094e6;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow5_col0 {
#             background-color:  #dde2f8;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow6_col0 {
#             background-color:  #a0afec;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow7_col0 {
#             background-color:  #e8ecfa;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow8_col0 {
#             background-color:  #c3cdf3;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow9_col0 {
#             background-color:  #e3e8f9;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow10_col0 {
#             background-color:  #e7ebfa;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow11_col0 {
#             background-color:  #e7ebfa;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow12_col0 {
#             background-color:  #778ce4;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow13_col0 {
#             background-color:  #d9dff7;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow14_col0 {
#             background-color:  #e3e7f9;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow15_col0 {
#             background-color:  #778ce4;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow16_col0 {
#             background-color:  #e2e6f9;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow17_col0 {
#             background-color:  #eaedfb;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow18_col0 {
#             background-color:  #dce1f8;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow19_col0 {
#             background-color:  #dde2f8;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow20_col0 {
#             background-color:  #c3cdf3;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow21_col0 {
#             background-color:  #d9dff7;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow22_col0 {
#             background-color:  #e2e6f9;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow23_col0 {
#             background-color:  #a8b6ee;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow24_col0 {
#             background-color:  #c8d0f4;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow25_col0 {
#             background-color:  #a0afec;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow26_col0 {
#             background-color:  #e7eafa;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow27_col0 {
#             background-color:  #e8ecfa;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow28_col0 {
#             background-color:  #e3e8f9;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow29_col0 {
#             background-color:  #e3e7f9;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow30_col0 {
#             background-color:  #eaedfb;
#             color:  #000000;
#         }    #T_2f324600_1705_11ea_b211_887873aedd0frow31_col0 {
#             background-color:  #a8b6ee;
#             color:  #000000;
#         }</style><table id="T_2f324600_1705_11ea_b211_887873aedd0f" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >support</th>    </tr>    <tr>        <th class="index_name level0" >antecedents</th>        <th class="index_name level1" >consequents</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel0_row0" class="row_heading level0 row0" rowspan=4>3C</th>
#                         <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row0" class="row_heading level1 row0" >休閒生活</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow0_col0" class="data row0 col0" >0.219646</td>
#             </tr>
#             <tr>
#                                 <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row1" class="row_heading level1 row1" >書籍</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow1_col0" class="data row1 col0" >0.0735833</td>
#             </tr>
#             <tr>
#                                 <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row2" class="row_heading level1 row2" >服飾/配件</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow2_col0" class="data row2 col0" >0.104799</td>
#             </tr>
#             <tr>
#                                 <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row3" class="row_heading level1 row3" >美食</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow3_col0" class="data row3 col0" >0.0559721</td>
#             </tr>
#             <tr>
#                         <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel0_row4" class="row_heading level0 row4" rowspan=4>休閒生活</th>
#                         <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row4" class="row_heading level1 row4" >3C</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow4_col0" class="data row4 col0" >0.219646</td>
#             </tr>
#             <tr>
#                                 <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row5" class="row_heading level1 row5" >書籍</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow5_col0" class="data row5 col0" >0.0716443</td>
#             </tr>
#             <tr>
#                                 <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row6" class="row_heading level1 row6" >服飾/配件</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow6_col0" class="data row6 col0" >0.168838</td>
#             </tr>
#             <tr>
#                                 <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row7" class="row_heading level1 row7" >美食</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow7_col0" class="data row7 col0" >0.0534762</td>
#             </tr>
#             <tr>
#                         <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel0_row8" class="row_heading level0 row8" rowspan=2>保健</th>
#                         <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row8" class="row_heading level1 row8" >書籍</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow8_col0" class="data row8 col0" >0.112608</td>
#             </tr>
#             <tr>
#                                 <th id="T_2f324600_1705_11ea_b211_887873aedd0flevel1_row9" class="row_heading level1 row9" >美食</th>
#                         <td id="T_2f324600_1705_11ea_b211_887873aedd0frow9_col0" class="data row9 col0" >0.0613498</td>
#             </tr>
#             <tr>
#                         <th id="T_2f32
